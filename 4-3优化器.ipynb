# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
# 载入数据库
mnist = input_data.read_data_sets('MNIST_data',one_hot=True)

# 每个批次的大小
batch_size = 100
# 计算一共有多少个批次
n_batch = mnist.train.num_examples //batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

# 创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)) + b

# 定义二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
# 使用梯度下降法
# train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
# train_step = tf.train.AdamOptimizer(1e-3).minimize(loss)
train_step = tf.train.AdadeltaOptimizer(1).minimize(loss)
# train_step = tf.train.AdagradOptimizer(0.1).minimize(loss)
# train_step = tf.train.AdagradDAOptimizer(0.1).minimize(loss)
# train_step = tf.train.MomentumOptimizer(0.1).minimize(loss)


# 初始化变量
init =  tf.global_variables_initializer()

# 结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1)) # argmax返回一维常量中最大值所在的位置
# 求准确率
accurary = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(100):
         for batch in range(n_batch):
                batch_xs,batch_ys = mnist.train.next_batch(batch_size)
                sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
         acc = sess.run(accurary,feed_dict={x:mnist.test.images,y:mnist.test.labels})
         print("Iter" + str(epoch) + ",Testing Accurary " + str(acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accurary 0.875
# Iter1,Testing Accurary 0.8946
# Iter2,Testing Accurary 0.9018
# Iter3,Testing Accurary 0.907
# Iter4,Testing Accurary 0.9095
# Iter5,Testing Accurary 0.9117
# Iter6,Testing Accurary 0.9132
# Iter7,Testing Accurary 0.9146
# Iter8,Testing Accurary 0.9167
# Iter9,Testing Accurary 0.9164
# Iter10,Testing Accurary 0.9177
# Iter11,Testing Accurary 0.9189
# Iter12,Testing Accurary 0.9199
# Iter13,Testing Accurary 0.9195
# Iter14,Testing Accurary 0.9198
# Iter15,Testing Accurary 0.9213
# Iter16,Testing Accurary 0.9215
# Iter17,Testing Accurary 0.9225
# Iter18,Testing Accurary 0.9226
# Iter19,Testing Accurary 0.923
# Iter20,Testing Accurary 0.9235
# Iter21,Testing Accurary 0.9242
# Iter22,Testing Accurary 0.9248
# Iter23,Testing Accurary 0.9246
# Iter24,Testing Accurary 0.9257
# Iter25,Testing Accurary 0.9247
# Iter26,Testing Accurary 0.9254
# Iter27,Testing Accurary 0.9253
# Iter28,Testing Accurary 0.9256
# Iter29,Testing Accurary 0.9257
# Iter30,Testing Accurary 0.9262
# Iter31,Testing Accurary 0.9263
# Iter32,Testing Accurary 0.9263
# Iter33,Testing Accurary 0.9266
# Iter34,Testing Accurary 0.9265
# Iter35,Testing Accurary 0.9263
# Iter36,Testing Accurary 0.9269
# Iter37,Testing Accurary 0.9263
# Iter38,Testing Accurary 0.9261
# Iter39,Testing Accurary 0.9265
# Iter40,Testing Accurary 0.9264
# Iter41,Testing Accurary 0.9266
# Iter42,Testing Accurary 0.9268
# Iter43,Testing Accurary 0.9272
# Iter44,Testing Accurary 0.9273
# Iter45,Testing Accurary 0.9269
# Iter46,Testing Accurary 0.9279
# Iter47,Testing Accurary 0.9271
# Iter48,Testing Accurary 0.9278
# Iter49,Testing Accurary 0.9271
# Iter50,Testing Accurary 0.9275
# Iter51,Testing Accurary 0.9274
# Iter52,Testing Accurary 0.928
# Iter53,Testing Accurary 0.9271
# Iter54,Testing Accurary 0.9274
# Iter55,Testing Accurary 0.9277
# Iter56,Testing Accurary 0.9283
# Iter57,Testing Accurary 0.9279
# Iter58,Testing Accurary 0.9281
# Iter59,Testing Accurary 0.9274
# Iter60,Testing Accurary 0.9278
# Iter61,Testing Accurary 0.9279
# Iter62,Testing Accurary 0.9284
# Iter63,Testing Accurary 0.928
# Iter64,Testing Accurary 0.9279
# Iter65,Testing Accurary 0.9285
# Iter66,Testing Accurary 0.9285
# Iter67,Testing Accurary 0.9275
# Iter68,Testing Accurary 0.9292
# Iter69,Testing Accurary 0.9284
# Iter70,Testing Accurary 0.9284
# Iter71,Testing Accurary 0.9288
# Iter72,Testing Accurary 0.9285
# Iter73,Testing Accurary 0.928
# Iter74,Testing Accurary 0.9289
# Iter75,Testing Accurary 0.9278
# Iter76,Testing Accurary 0.928
# Iter77,Testing Accurary 0.9283
# Iter78,Testing Accurary 0.9285
# Iter79,Testing Accurary 0.9282
# Iter80,Testing Accurary 0.9288
# Iter81,Testing Accurary 0.9291
# Iter82,Testing Accurary 0.9282
# Iter83,Testing Accurary 0.9293
# Iter84,Testing Accurary 0.929
# Iter85,Testing Accurary 0.929
# Iter86,Testing Accurary 0.9291
# Iter87,Testing Accurary 0.9292
# Iter88,Testing Accurary 0.9293
# Iter89,Testing Accurary 0.9295
# Iter90,Testing Accurary 0.9294
# Iter91,Testing Accurary 0.9288
# Iter92,Testing Accurary 0.929
# Iter93,Testing Accurary 0.9291
# Iter94,Testing Accurary 0.9292
# Iter95,Testing Accurary 0.9297
# Iter96,Testing Accurary 0.9292
# Iter97,Testing Accurary 0.9287
# Iter98,Testing Accurary 0.9297
# Iter99,Testing Accurary 0.9288
